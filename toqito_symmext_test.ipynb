# %%
from toqito.state_props.is_separable import _dps_hierarchy_criterion
from bound_entangled.c3_otimes_c3 import horodecki
import numpy as np
from bound_entangled.c3_otimes_c3 import cross_hatch , tiles_upb
import cvxpy as cp

print(cp.installed_solvers())

state = cross_hatch() * (1-0.64) + tiles_upb() * 0.64
# Out:
# ['CLARABEL', 'SCS', 'GLPK', 'GLPK_MI', 'CVXOPT', 'SCIPY', 'HIGHS', 'OSQP']

# %%
print(_dps_hierarchy_criterion(state, [3,3], 3, 1e-8))
# Out:
# Failure:interrupted
# ...
# None
